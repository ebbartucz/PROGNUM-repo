# %% [markdown]
# Answers for Week 1
#
# * Name: Eszter Bartucz
# * Username: ebbartucz
# * Student s-number: S6362311
# * Group (AS1, etc.): AS4

# %% [markdown]
# Question 1.2:

# %%
x=22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi=22/7 #Processed on Jupyter Hub

# %% [markdown]
# Question 1.5:

# %%
import math
from scipy.constants import G

m_moon=7.342*10**22
m_earth=5.9722*10**24
d=385000.6

# %%
F=(G*m_moon*m_earth)/(d*1000)**2
print("The gravitational pull is", F ,"N.")
# Out:
# The gravitational pull is 1.974384051807571e+20 N.

# %% [markdown]
# Question 1.15:

# %% [markdown]
# 1. The command pwd will print the path to Downloads thus /home/localuser3/Downloads.
# 2. The notation . refers to the current directory and .. refers to the parent directory.

# %% [markdown]
# Question 1.16:

# %% [markdown]
# cd ~/Desktop (cd ../Desktop)

# %% [markdown]
# Question 1.10:

# %% [markdown]
# I will download this notebook as a .py file.
# ![image.png](attachment:b56c0423-8425-4ee5-affc-3acb2a72c6ad.png)

# %% [markdown]
# (Q1.3)

# %%
x=6
x=x-1

print(x)
# Out:
# 30

# %% [markdown]
# Question 1.11

# %% [markdown]
# ![Screenshot%20from%202026-02-12%2014-26-38.png](attachment:Screenshot%20from%202026-02-12%2014-26-38.png)
