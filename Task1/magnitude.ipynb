# %%
# Sirius data
apparentMagnitude = -1.46
absoluteMagnitude = 1.45

# The distance is related to the magnitudes as m-M=5.Log(d/10)
# 1 Parsec = 3.26164 ly

m = apparentMagnitude
M = absoluteMagnitude

d = 10.0 * pow( 10.0, (m-M)/5.0 ) * 3.26164

print(f"The distance of Sirius: {d} ly")
# Out:
# The distance of Sirius: 8.53957042692737 ly

# %%
m = float(input(f"The apparent magnitude: "))
M = float(input(f"The absolute magnitude: "))

d = 10.0 * pow( 10.0, (m-M)/5.0 ) * 3.26164

print(f"The estimated distance of Sirius: {d} ly")
